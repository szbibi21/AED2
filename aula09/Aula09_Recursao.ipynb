# %% [markdown]
# ![Algoritmos e Estrutura de Dados II - Prof Piva](AED2_banner.jpg)

# %% [markdown]
# ## Aula 9 - Recursão

# %% [markdown]
# ![Recursao. Chocolate Droste](recursao.jpg)

# %% [markdown]
# #### Mostrar mensagens

# %%
for _ in range(5):
  print('Recursão')

# %%
def recursao(i):
  print('Recursão')
  i += 1
  if i == 5:
    return
  else:
    recursao(i)

# %%
recursao(0)
# Out:
# Recursão
# Recursão
# Recursão
# Recursão
# Recursão

# %%
recursao(4)
# Out:
# Recursão

# %% [markdown]
# #### Somar valores

# %%
def soma1(n):
  soma = 0
  for i in range(n + 1):
    soma += i
  return soma

# %%
soma1(5)
# Out:
# 15

# %%
def soma2(n):
  if n == 0:
    return 0

  return n + soma2(n - 1)

# %%
soma2(5)
# Out:
# 15

# %%
# %timeit soma1(100)
# Out:
# 7.43 μs ± 141 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit soma2(100)
# Out:
# 16.5 μs ± 360 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# #### Fatorial

# %%
def fatorial(n):
   if n > 1:
      return n * fatorial(n-1)
   else:
      return 1

# %%
fatorial(5)
# Out:
# 120

# %% [markdown]
# ### Fibonacci

# %% [markdown]
# #### Fibonacci Recursivo

# %%
def fib(n):
    """A função Fibonacci recursiva."""
    if n < 3:
        return 1
    else:
       return fib(n - 1) + fib(n - 2)

# %%
# %timeit fib(20)
# Out:
# 2.11 ms ± 49.5 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### Fibonacci Linear

# %%
def fibonacci(N):
    if N <= 0:
        return "O valor de N deve ser maior que 0"
    elif N == 1:
        return 1
    elif N == 2:
        return 1

    sum, first, second = 1, 1, 1
    count = 3

    while count <= N:
        sum = first + second
        first = second
        second = sum
        count += 1

    return sum

# %%
def fib2(n):
    for i in range(1, n+1):
        fibonacci(i)
    return

# %%
# %timeit fib2(20)
# Out:
# 27.5 μs ± 730 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Exercícios

# %% [markdown]
# #### Exercício 1: Soma de uma Lista
# Implemente uma função recursiva para calcular a soma dos elementos de uma lista de números inteiros. A função deve receber a lista como parâmetro e retornar a soma dos seus elementos.
#
# Descrição:
# - A função recursiva deve ser chamada repetidamente até que todos os elementos da lista sejam somados.
# - Caso base: se a lista estiver vazia, o resultado deve ser 0.
# - Caso recursivo: a soma do primeiro elemento da lista com a soma dos elementos restantes.

# %%
# Resposta

# %% [markdown]
# #### Exercício 2: Potenciação Recursiva
# Implemente uma função recursiva para calcular a potência de um número inteiro. A função deve receber dois parâmetros: a base e o expoente, e retornar o resultado da base elevada ao expoente.
#
# Descrição:
# - O caso base ocorre quando o expoente é 0, onde qualquer número elevado a 0 é 1.
# - O caso recursivo multiplica a base por ela mesma, diminuindo o expoente em 1 a cada chamada recursiva.

# %%
# Resposta

# %% [markdown]
# ## Fim da Aula 9
