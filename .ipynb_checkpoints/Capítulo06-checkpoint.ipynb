# %% [markdown]
# # Capítulo 6

# %% [markdown]
# ### Pilhas

# %% [markdown]
# ## Exercícios

# %% [raw]
# 1. (ENADE) Sobre uma pilha recém-criada (vazia), considere as seguintes operações em ordem: push(5),
# push(10), pop(), push(7), push(3), pop(). Qual será o resultado da última operação pop(), e qual a configuração
# final da pilha?
#
# A. O último pop() retorna 3; pilha final = [5, 10, 7].
# B. O último pop() retorna 7; pilha final = [5, 10].
# C. O último pop() retorna 10; pilha final = [5, 7].
# D. O último pop() retorna 7; pilha final = [5, 10, 7].
# E. O último pop() retorna 3; pilha final = [5, 10]

# %% [markdown]
# ### Resposta
# 1. E. O último pop() retorna 3; pilha final = [5, 10]

# %% [raw]
# 2. (ENADE) Considere a implementação da classe Stack mostrada acima. Após executar:
# p = Stack()
# p.push('a')
# p.push('b')
# x = p.peek()
# p.pop()
# y = p.peek()
# Quais são os valores de x e y após essas operações?
# A. x = 'a', y = 'b'
# B. x = 'b', y = 'a'
# C. x = 'b', y = 'b'
# D. x = 'a', y = 'a'
# E. x = None, y = None

# %% [markdown]
# ### Resposta
# 2. B. x = 'b', y = 'a'

# %% [raw]
# 3. (ENADE) Analise a afirmação a seguir sobre pilhas (stacks):
# I. Uma pilha vazia não permite operação pop.
# II. Na pilha, é possível inserir (empilhar) um elemento em qualquer posição.
# III. Na pilha, existe um único ponto de acesso aos dados, conhecido como topo.
# IV. A operação push adiciona um elemento no final da fila.
# Quais são as afirmações corretas?
# A. I e III apenas.
# B. I, II e III apenas.
# C. II e IV apenas.
# D. I, III e IV apenas.
# E. Todas são corretas

# %% [markdown]
# ### Resposta
# 3. A. I e III apenas.

# %% [raw]
# 4. (ENADE) Suponha que temos uma pilha inicialmente vazia e executamos: push(1), push(2), push(3), pop(),
# push(4), pop(), pop(), pop(). Quantas vezes ocorre uma tentativa de pop() em uma pilha vazia?
# A. 0 vezes
# B. 1 vez
# C. 2 vezes
# D. 3 vezes
# E. 4 vezes

# %% [markdown]
# ### Resposta
# 4. A. 0 vezes

# %% [raw]
# 5. (Prática) Implemente em Python uma função decimal_para_hexa(n) que converta um número decimal nãonegativo n para sua representação hexadecimal como string, usando uma pilha. (Por exemplo,
# decimal_para_hexa(26) deve retornar "1A".)

# %%
def decimal_para_hexa(n):
    if n == 0: return "0"
    hex_digits = "0123456789ABCDEF"
    stack = []
    while n > 0:
        stack.append(hex_digits[n % 16])
        n //= 16
    return "".join(reversed(stack))

# %% [raw]
# 6. (Prática) Escreva uma função balanceia_colchetes(expressao) que, dada uma string contendo (, ), {, } e outros
# caracteres, determine se os parênteses e chaves estão balanceados. Use pilhas no seu algoritmo. Por exemplo,
# "({[]})" está balanceado, mas "({[}])" não está.

# %%
def balanceia_colchetes(expressao):
    stack = []
    pairs = {')': '(', '}': '{', ']': '['}
    for char in expressao:
        if char in "({[":
            stack.append(char)
        elif char in ")}]":
            if not stack or stack.pop() != pairs[char]:
                return False
    return not stack

# %% [markdown]
# # Projetos

# %% [markdown]
# ## Projeto 1 – Histórico de Filtros em Dashboard de Dados

# %% [raw]
# Contexto:
# Em aplicações de ciência de dados para negócios, usuários interagem com dashboards aplicando
# filtros e transformações aos dados (por exemplo, em tabelas ou gráficos interativos). É útil permitir que o usuário
# desfaça filtros aplicados (por exemplo, revertendo ao estado anterior dos dados) sem recarregar tudo do início.
#
# Problema:
# Como implementar um mecanismo de histórico de operações que guarde estados anteriores dos
# dados ao aplicar filtros, para que o usuário possa desfazer a última ação?

# %%
class DashboardHistory:
    def __init__(self, estado_inicial):
        self.historico = []
        self.estado_atual = estado_inicial

    def aplicar_filtro(self, novo_filtro):
        self.historico.append(self.estado_atual)
        self.estado_atual = f"Dados filtrados por: {novo_filtro}"
        print(f"Filtro aplicado. Estado atual: {self.estado_atual}")

    def desfazer(self):
        if self.historico:
            self.estado_atual = self.historico.pop()
            print(f"Desfeito! Estado restaurado: {self.estado_atual}")
        else:
            print("Não há mais ações para desfazer.")

dash = DashboardHistory("Dados Brutos")
dash.aplicar_filtro("Vendas 2023")
dash.aplicar_filtro("Região Sul")
dash.desfazer()
# Out:
# Filtro aplicado. Estado atual: Dados filtrados por: Vendas 2023
# Filtro aplicado. Estado atual: Dados filtrados por: Região Sul
# Desfeito! Estado restaurado: Dados filtrados por: Vendas 2023

# %% [markdown]
# ## Projeto 2 – Calculadora de Expressões Aritméticas

# %% [raw]
# Contexto:
# Muitas calculadoras e programas de matemática interpretam expressões aritméticas infixas (como
# "3 + 4 * (2 - 1)"). Uma maneira clássica de avaliar tais expressões é converter para notação pós-fixa (RPN) ou usar
# pilhas para operar em tempo de execução.
#
# Problema:
# Escrever um programa Python que avalie uma expressão matemática em infixo contendo +, -, *, /, e
# parênteses. Queremos usar pilhas para lidar com a precedência de operadores e a aninhamento de parênteses.

# %%
def calcular(expressao):
    def aplicar_op(valores, operadores):
        b = valores.pop()
        a = valores.pop()
        op = operadores.pop()
        if op == '+': valores.append(a + b)
        if op == '-': valores.append(a - b)
        if op == '*': valores.append(a * b)
        if op == '/': valores.append(a / b)

    precedencia = {'+': 1, '-': 1, '*': 2, '/': 2}
    valores = []
    operadores = []
    i = 0
    while i < len(expressao):
        if expressao[i] == ' ':
            i += 1; continue
        
        if expressao[i].isdigit():
            val = 0
            while i < len(expressao) and expressao[i].isdigit():
                val = (val * 10) + int(expressao[i])
                i += 1
            valores.append(val)
            continue
        
        if expressao[i] == '(':
            operadores.append('(')
        elif expressao[i] == ')':
            while operadores[-1] != '(':
                aplicar_op(valores, operadores)
            operadores.pop() # Remove '('
        else:
            while (operadores and operadores[-1] != '(' and 
                   precedencia[operadores[-1]] >= precedencia[expressao[i]]):
                aplicar_op(valores, operadores)
            operadores.append(expressao[i])
        i += 1

    while operadores:
        aplicar_op(valores, operadores)
    
    return valores[0]

resultado = calcular("3+4*(2-1)")
print(f"Resultado: {resultado}")
# Out:
# Resultado: 7
